# %%
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

(Xtrain,ytrain),(Xtest,ytest) = keras.datasets.mnist.load_data()
print(Xtrain.shape)
print(ytrain.shape)
print(Xtest.shape)
print(ytest.shape)

#data scaling
Xtrain=Xtrain/Xtrain.max()
Xtest=Xtest/Xtest.max()
print(len(np.unique(ytrain)))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)
# 10

# %%
import numpy as np
for i in range(1,36+1,1):
  temp= np.random.randint(0,60000)
  im=Xtrain[temp,:,:]
  lab=ytrain[temp]
  plt.subplot(6,6,i)
  plt.imshow(im,cmap='gray')
  plt.axis('off')
  plt.title(lab)
plt.show()

# %%
#create an empty nn feed forward
nn_model= keras.Sequential()
nn_model.add(keras.layers.Flatten(input_shape=(Xtrain.shape[1],Xtrain.shape[2])))
nn_model.add(keras.layers.Dense(128,activation='relu')) #hidden layer1
nn_model.add(keras.layers.Dense(256,activation='relu')) #hidden layer2
nn_model.add(keras.layers.Dense(256,activation='relu')) #hidden layer3

nn_model.add(keras.layers.Dense(len(np.unique(ytrain)))) #output layer


#optimizer add
nn_model.compile(optimizer="SGD",loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])
print(nn_model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dense_2 (Dense)             (None, 256)               65792
#
#  dense_3 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 201866 (788.54 KB)
# Trainable params: 201866 (788.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
history=nn_model.fit(Xtrain,ytrain,epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.6514 - accuracy: 0.8286
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2738 - accuracy: 0.9209
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2163 - accuracy: 0.9370
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1803 - accuracy: 0.9478
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1549 - accuracy: 0.9540
# Epoch 6/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1356 - accuracy: 0.9604
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1207 - accuracy: 0.9642
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1083 - accuracy: 0.9680
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0984 - accuracy: 0.9708
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0898 - accuracy: 0.9735

# %%
# visualize the training loss and acc
plt.figure(1,(4,2))
plt.plot(history.epoch,history.history['loss'],'--ko')
plt.grid('on')
plt.title('Training loss graph ')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.figure(2,(4,2))
plt.plot(history.epoch,history.history['accuracy'],'--ko')
plt.grid('on')
plt.title('Training accuracy graph ')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
# evaluate the test data

[loss, acc] = nn_model.evaluate(Xtest,ytest)
print('Loss:',loss)
print("Testing Accuracy",acc)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0956 - accuracy: 0.9704
# Loss: 0.0955926924943924
# Testing Accuracy 0.9703999757766724

# %%
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

(Xtrain,ytrain),(Xtest,ytest) = keras.datasets.fashion_mnist.load_data()
print(Xtrain.shape)
print(ytrain.shape)
print(Xtest.shape)
print(ytest.shape)

#data scaling
Xtrain=Xtrain/Xtrain.max()
Xtest=Xtest/Xtest.max()
print(len(np.unique(ytrain)))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 1s 0us/step
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)
# 10

# %%
import numpy as np
plt.figure(1,( 10,10))
for i in range(1,36+1,1):
  temp= np.random.randint(0,60000)
  im=Xtrain[temp,:,:]
  lab=ytrain[temp]
  plt.subplot(6,6,i)
  plt.imshow(im,cmap='gray')
  plt.axis('off')
  plt.title(lab)
plt.show()

# %%
#create an empty nn feed forward
nn_model= keras.Sequential()
nn_model.add(keras.layers.Flatten(input_shape=(Xtrain.shape[1],Xtrain.shape[2])))
nn_model.add(keras.layers.Dense(128,activation='relu')) #hidden layer1
nn_model.add(keras.layers.Dense(256,activation='relu')) #hidden layer2
nn_model.add(keras.layers.Dense(256,activation='relu')) #hidden layer3

nn_model.add(keras.layers.Dense(len(np.unique(ytrain)))) #output layer


#optimizer add
nn_model.compile(optimizer="SGD",loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])
print(nn_model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 784)               0
#
#  dense_8 (Dense)             (None, 128)               100480
#
#  dense_9 (Dense)             (None, 256)               33024
#
#  dense_10 (Dense)            (None, 256)               65792
#
#  dense_11 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 201866 (788.54 KB)
# Trainable params: 201866 (788.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
history=nn_model.fit(Xtrain,ytrain,epochs=20)
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.7617 - accuracy: 0.7417
# Epoch 2/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4872 - accuracy: 0.8295
# Epoch 3/20
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.4365 - accuracy: 0.8446
# Epoch 4/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4061 - accuracy: 0.8565
# Epoch 5/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3850 - accuracy: 0.8632
# Epoch 6/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3675 - accuracy: 0.8675
# Epoch 7/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3540 - accuracy: 0.8724
# Epoch 8/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3419 - accuracy: 0.8762
# Epoch 9/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3314 - accuracy: 0.8802
# Epoch 10/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3228 - accuracy: 0.8820
# Epoch 11/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3149 - accuracy: 0.8849
# Epoch 12/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3064 - accuracy: 0.8881
# Epoch 13/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3012 - accuracy: 0.8904
# Epoch 14/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2935 - accuracy: 0.8932
# Epoch 15/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2868 - accuracy: 0.8950
# Epoch 16/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2803 - accuracy: 0.8978
# Epoch 17/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2763 - accuracy: 0.8979
# Epoch 18/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2698 - accuracy: 0.9003
# Epoch 19/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2652 - accuracy: 0.9032
# Epoch 20/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2599 - accuracy: 0.9049

# %%
# visualize the training loss and acc
plt.figure(1,(4,2))
plt.plot(history.epoch,history.history['loss'],'--ko')
plt.grid('on')
plt.title('Training loss graph ')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.figure(2,(4,2))
plt.plot(history.epoch,history.history['accuracy'],'--ko')
plt.grid('on')
plt.title('Training accuracy graph ')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
# evaluate the test data

[loss, acc] = nn_model.evaluate(Xtest,ytest)
print('Loss:',loss)
print("Testing Accuracy",acc)
# Out:
# 313/313 [==============================] - 2s 3ms/step - loss: 0.3353 - accuracy: 0.8818
# Loss: 0.335334837436676
# Testing Accuracy 0.8817999958992004

# %%
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

(Xtrain,ytrain),(Xtest,ytest) = keras.datasets.cifar10.load_data()
print(Xtrain.shape)
print(ytrain.shape)
print(Xtest.shape)
print(ytest.shape)

#data scaling
Xtrain=Xtrain/Xtrain.max()
Xtest=Xtest/Xtest.max()
print(len(np.unique(ytrain)))
# Out:
# (50000, 32, 32, 3)
# (50000, 1)
# (10000, 32, 32, 3)
# (10000, 1)
# 10

# %%
import numpy as np
plt.figure(1,( 10,10))
for i in range(1,36+1,1):
  temp= np.random.randint(0,50000)
  im=Xtrain[temp,:,:]
  lab=ytrain[temp]
  plt.subplot(6,6,i)
  plt.imshow(im,cmap='gray')
  plt.axis('off')
  plt.title(lab)
plt.show()

# %%
#create an empty nn feed forward
nn_model= keras.Sequential()
nn_model.add(keras.layers.Flatten(input_shape=(Xtrain.shape[1],Xtrain.shape[2],Xtrain.shape[3])))
nn_model.add(keras.layers.Dense(128,activation='relu')) #hidden layer1
nn_model.add(keras.layers.Dense(256,activation='relu')) #hidden layer2
nn_model.add(keras.layers.Dense(256,activation='relu')) #hidden layer3

nn_model.add(keras.layers.Dense(len(np.unique(ytrain)))) #output layer


#optimizer add
nn_model.compile(optimizer="SGD",loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])
print(nn_model.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_3 (Flatten)         (None, 3072)              0
#
#  dense_12 (Dense)            (None, 128)               393344
#
#  dense_13 (Dense)            (None, 256)               33024
#
#  dense_14 (Dense)            (None, 256)               65792
#
#  dense_15 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 494730 (1.89 MB)
# Trainable params: 494730 (1.89 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
history=nn_model.fit(Xtrain,ytrain,epochs=80)
# Out:
# Epoch 1/80
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.9161 - accuracy: 0.3069
# Epoch 2/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.7151 - accuracy: 0.3863
# Epoch 3/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.6326 - accuracy: 0.4172
# Epoch 4/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5726 - accuracy: 0.4417
# Epoch 5/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5259 - accuracy: 0.4579
# Epoch 6/80
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.4837 - accuracy: 0.4709
# Epoch 7/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.4509 - accuracy: 0.4838
# Epoch 8/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.4204 - accuracy: 0.4927
# Epoch 9/80
# 1563/1563 [==============================] - 5s 4ms/step - loss: 1.3920 - accuracy: 0.5031
# Epoch 10/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3687 - accuracy: 0.5137
# Epoch 11/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3469 - accuracy: 0.5211
# Epoch 12/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3248 - accuracy: 0.5296
# Epoch 13/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3021 - accuracy: 0.5369
# Epoch 14/80
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.2855 - accuracy: 0.5455
# Epoch 15/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.2684 - accuracy: 0.5503
# Epoch 16/80
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.2492 - accuracy: 0.5590
# Epoch 17/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.2320 - accuracy: 0.5639
# Epoch 18/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.2144 - accuracy: 0.5687
# Epoch 19/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.2000 - accuracy: 0.5750
# Epoch 20/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.1820 - accuracy: 0.5813
# Epoch 21/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.1665 - accuracy: 0.5860
# Epoch 22/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.1535 - accuracy: 0.5922
# Epoch 23/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.1375 - accuracy: 0.5967
# Epoch 24/80
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.1226 - accuracy: 0.6025
# Epoch 25/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.1083 - accuracy: 0.6061
# Epoch 26/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.0922 - accuracy: 0.6133
# Epoch 27/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.0790 - accuracy: 0.6176
# Epoch 28/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.0641 - accuracy: 0.6225
# Epoch 29/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.0524 - accuracy: 0.6270
# Epoch 30/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.0380 - accuracy: 0.6349
# Epoch 31/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.0224 - accuracy: 0.6384
# Epoch 32/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.0089 - accuracy: 0.6417
# Epoch 33/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.9941 - accuracy: 0.6467
# Epoch 34/80
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.9814 - accuracy: 0.6529
# Epoch 35/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.9704 - accuracy: 0.6560
# Epoch 36/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.9566 - accuracy: 0.6630
# Epoch 37/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.9445 - accuracy: 0.6647
# Epoch 38/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.9294 - accuracy: 0.6696
# Epoch 39/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.9186 - accuracy: 0.6755
# Epoch 40/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.9075 - accuracy: 0.6793
# Epoch 41/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.8900 - accuracy: 0.6848
# Epoch 42/80
# 1563/1563 [==============================] - 5s 4ms/step - loss: 0.8787 - accuracy: 0.6900
# Epoch 43/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.8643 - accuracy: 0.6942
# Epoch 44/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.8544 - accuracy: 0.6954
# Epoch 45/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.8406 - accuracy: 0.7024
# Epoch 46/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.8285 - accuracy: 0.7073
# Epoch 47/80
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.8149 - accuracy: 0.7106
# Epoch 48/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.8026 - accuracy: 0.7147
# Epoch 49/80
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.7893 - accuracy: 0.7219
# Epoch 50/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.7748 - accuracy: 0.7249
# Epoch 51/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.7629 - accuracy: 0.7322
# Epoch 52/80
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.7527 - accuracy: 0.7327
# Epoch 53/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.7379 - accuracy: 0.7378
# Epoch 54/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.7247 - accuracy: 0.7437
# Epoch 55/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.7187 - accuracy: 0.7445
# Epoch 56/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.7077 - accuracy: 0.7489
# Epoch 57/80
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.6919 - accuracy: 0.7560
# Epoch 58/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.6808 - accuracy: 0.7575
# Epoch 59/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.6666 - accuracy: 0.7633
# Epoch 60/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.6566 - accuracy: 0.7688
# Epoch 61/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.6453 - accuracy: 0.7729
# Epoch 62/80
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.6313 - accuracy: 0.7769
# Epoch 63/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.6208 - accuracy: 0.7805
# Epoch 64/80
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.6104 - accuracy: 0.7821
# Epoch 65/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.5977 - accuracy: 0.7875
# Epoch 66/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.5882 - accuracy: 0.7917
# Epoch 67/80
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.5702 - accuracy: 0.7987
# Epoch 68/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.5635 - accuracy: 0.8008
# Epoch 69/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.5572 - accuracy: 0.8015
# Epoch 70/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.5407 - accuracy: 0.8092
# Epoch 71/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.5309 - accuracy: 0.8126
# Epoch 72/80
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.5196 - accuracy: 0.8163
# Epoch 73/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.5114 - accuracy: 0.8210
# Epoch 74/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4972 - accuracy: 0.8242
# Epoch 75/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4938 - accuracy: 0.8264
# Epoch 76/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4784 - accuracy: 0.8295
# Epoch 77/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4707 - accuracy: 0.8350
# Epoch 78/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4605 - accuracy: 0.8374
# Epoch 79/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4434 - accuracy: 0.8434
# Epoch 80/80
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.4413 - accuracy: 0.8442

# %%
# visualize the training loss and acc
plt.figure(1,(8,4))
plt.plot(history.epoch,history.history['loss'],'--ko')
plt.grid('on')
plt.title('Training loss graph ')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.figure(2,(8,4))
plt.plot(history.epoch,history.history['accuracy'],'--ko')
plt.grid('on')
plt.title('Training accuracy graph ')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
# evaluate the test data

[loss, acc] = nn_model.evaluate(Xtest,ytest)
print('Loss:',loss)
print("Testing Accuracy",acc)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 2.0498 - accuracy: 0.5208
# Loss: 2.04982852935791
# Testing Accuracy 0.520799994468689
